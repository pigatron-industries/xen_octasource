# %%
from simulator import *
from discrete_attractors2d import *

simulation = SystemSimulator(TinkerbellMap(Vector([0.1, 0.1])))
simulation.simulate(10000)
simulation.plot2D()

# %%
from simulator import *
from continuous_attractors3d import *

simulation = SystemSimulator(CliffordAttractor(Vector([0.1, 0.1]), a=-1.7, b=1.3, c=-0.1, d=-1.21))
simulation.simulate(10000)
simulation.plot2D()

simulation = SystemSimulator(CliffordAttractor(Vector([0.1, 0.1]), a=-1.7, b=1.8, c=-1.9, d=-0.4))
simulation.simulate(10000)
simulation.plot2D()

# %%
from simulator import *
from continuous_attractors3d import *


simulation = SystemSimulator(AizawaAttractor(Vector([0.1, 0.1, 0.1])))
simulation.simulate(10000)
# simulation.plot1D(axis=X)
# simulation.plot1D(axis=Y)
# simulation.plot1D(axis=Z)
# simulation.plot2D(axis=(X, Y))
simulation.plot2D(axis=(X, Z))
# simulation.plot2D(axis=(X, Z))
simulation.plotIsometric(45, -35)

# %%
from simulator import *
from continuous_attractors3d import *


simulation = SystemSimulator(DadrasAttractor(Vector([0.01, 0.01, 0.01])))
simulation.simulate(10000)
# simulation.plot1D(axis=X)
# simulation.plot1D(axis=Y)
# simulation.plot1D(axis=Z)
simulation.plot2D(axis=(X, Y))
simulation.plot2D(axis=(Y, Z))
simulation.plot2D(axis=(X, Z))
simulation.plotIsometric(45, -35)

# %%
from simulator import *
from continuous_attractors3d import *

simulation = SystemSimulator(HalvorsenAttractor(Vector([-0.1, 0.1, 0.1]), a = 3.5))
simulation.simulate(10000)
# simulation.plot1D(axis=X)
# simulation.plot1D(axis=Y)
# simulation.plot1D(axis=Z)
simulation.plotIsometric(angle1=45, angle2=-35)
simulation.plot2D(axis=(Z, X))
simulation.plot2D(axis=(X, Y))
simulation.plot2D(axis=(Y, Z))

# %%
from simulator import *
from continuous_attractors3d import *

simulation = SystemSimulator(ThomasAttractor(Vector([-0.1, 0.1, 0.1])))
simulation.simulate(100000)
# simulation.plot1D(axis=X)
# simulation.plot1D(axis=Y)
# simulation.plot1D(axis=Z)
simulation.plotIsometric(angle1=45, angle2=-35)
simulation.plot2D(axis=(Z, X))
simulation.plot2D(axis=(X, Y))
simulation.plot2D(axis=(Y, Z))

# %%
from simulator import *
from continuous_attractors3d import *

simulation = SystemSimulator(NoseHooverAttractor(Vector([-0.1, 0.1, 0.1])))
simulation.simulate(20000)
# simulation.plot1D(axis=X)
# simulation.plot1D(axis=Y)
# simulation.plot1D(axis=Z)
simulation.plotIsometric(angle1=45, angle2=-35)
simulation.plot2D(axis=(X, Y))
simulation.plot2D(axis=(Y, Z))
simulation.plot2D(axis=(Z, X))

# %%
from simulator import *
from continuous_attractors3d import *

simulation = SystemSimulator(HadleyAttractor(Vector([-0.1, 0.1, 0.1]), a = 1, b = 4.0, c = 8.0, d = 1.0))
simulation.simulate(10000)
# simulation.plot1D(axis=X)
# simulation.plot1D(axis=Y)
# simulation.plot1D(axis=Z)
# simulation.plotIsometric(angle1=45, angle2=-35)
# simulation.plot2D(axis=(Z, X))
# simulation.plot2D(axis=(X, Y))
simulation.plot2D(axis=(Y, Z))

# %%
from simulator import *
from discrete_attractors2d import *

simulation = SystemSimulator(HopalongAttractor(Vector([0.5, 0.5]), a = 0.4, b = 1, c = 0.7))
simulation.simulate(100000)
simulation.plot2D()

# %%
from simulator import *
from discrete_attractors2d import *

simulation = SystemSimulator(MetzAttractor(Vector([70, 100]), a = 4.15, b = 10))
simulation.simulate(10000)
simulation.plot2D()

# %%
from simulator import *
from continuous_attractors3d import *

simulation = SystemSimulator(LorenzMod2Attractor(Vector([-0.1, 0.1, 0.1]), a = 0.9, b = 5.0, c = 0.9, d = 1.0))
simulation.simulate(10000)
# simulation.plot1D(axis=X)
# simulation.plot1D(axis=Y)
# simulation.plot1D(axis=Z)
# simulation.plotIsometric(angle1=45, angle2=-35)
# simulation.plot2D(axis=(Z, X))
# simulation.plot2D(axis=(X, Y))
simulation.plot2D(axis=(Y, Z))
